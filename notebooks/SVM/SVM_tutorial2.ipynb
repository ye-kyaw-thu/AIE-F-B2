# %% [markdown]
# # Binary Classification with TinySVM Tutorial
# ### Dr. Ye Kyaw Thu, Lab Leader, Language Understanding Lab., AI Mario, Myanmar
# ### for AI Engineering (Fundamental) Class Students
# ### Date: 28 July 2026
# ### Last Updated: 16 Aug 2026
#
# Here, let's focus on binary classification!
# TinySVM: [http://chasen.org/~taku/software/TinySVM/](http://chasen.org/~taku/software/TinySVM/)
# UCI Iris Dataset: [https://archive.ics.uci.edu/dataset/53/iris](https://archive.ics.uci.edu/dataset/53/iris)
#
# Scikit-Learn's Official Documentation: [https://scikit-learn.org/stable/datasets/toy_dataset.html#iris-dataset](https://scikit-learn.org/stable/datasets/toy_dataset.html#iris-dataset)
#
# API Reference: [https://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_iris.html](https://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_iris.html)
#
# Kaggle Iris Dataset: [https://www.kaggle.com/datasets/uciml/iris](https://www.kaggle.com/datasets/uciml/iris)

# %% [markdown]
# ## TinySVM Installation

# %%
# %cd /home/ye/aif2/
# Out:
# /home/ye/aif2

# %%
# !wget wget http://chasen.org/~taku/software/TinySVM/src/TinySVM-0.09.tar.gz
# Out:
# --2026-07-28 22:17:57--  http://wget/
# Resolving wget (wget)... failed: Temporary failure in name resolution.
# wget: unable to resolve host address ‘wget’
# --2026-07-28 22:17:57--  http://chasen.org/~taku/software/TinySVM/src/TinySVM-0.09.tar.gz
# Resolving chasen.org (chasen.org)... 160.16.121.64
# Connecting to chasen.org (chasen.org)|160.16.121.64|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 317636 (310K) [application/x-gzip]
# Saving to: ‘TinySVM-0.09.tar.gz’
#
# TinySVM-0.09.tar.gz 100%[===================>] 310.19K   734KB/s    in 0.4s
#
# 2026-07-28 22:17:58 (734 KB/s) - ‘TinySVM-0.09.tar.gz’ saved [317636/317636]
#
# FINISHED --2026-07-28 22:17:58--
# Total wall clock time: 0.9s
# Downloaded: 1 files, 310K in 0.4s (734 KB/s)

# %% [markdown]
# **tar.gz ဖိုင်ကို ဖြေမယ်**

# %%
# !tar xzvf TinySVM-0.09.tar.gz
# Out:
# TinySVM-0.09/
# TinySVM-0.09/README
# TinySVM-0.09/stamp-h.in
# TinySVM-0.09/AUTHORS
# TinySVM-0.09/COPYING
# TinySVM-0.09/ChangeLog
# TinySVM-0.09/INSTALL
# TinySVM-0.09/Makefile.am
# TinySVM-0.09/Makefile.in
# TinySVM-0.09/NEWS
# TinySVM-0.09/THANKS
# TinySVM-0.09/acconfig.h
# TinySVM-0.09/aclocal.m4
# TinySVM-0.09/config.guess
# TinySVM-0.09/config.h.in
# TinySVM-0.09/config.sub
# TinySVM-0.09/configure
# TinySVM-0.09/configure.in
# TinySVM-0.09/install-sh
# TinySVM-0.09/ltconfig
# TinySVM-0.09/ltmain.sh
# TinySVM-0.09/missing
# TinySVM-0.09/mkinstalldirs
# TinySVM-0.09/tinysvm.spec.in
# TinySVM-0.09/tinysvm.spec
# TinySVM-0.09/src/
# TinySVM-0.09/src/Makefile.am
# TinySVM-0.09/src/Makefile.bcc32.in
# TinySVM-0.09/src/Makefile.in
# TinySVM-0.09/src/Makefile.msvc.in
# TinySVM-0.09/src/getopt.c
# TinySVM-0.09/src/getopt1.c
# TinySVM-0.09/src/getopt.h
# TinySVM-0.09/src/common.h
# TinySVM-0.09/src/param.cpp
# TinySVM-0.09/src/param.h
# TinySVM-0.09/src/kernel.h
# ...

# %%
# %cd TinySVM-0.09/
# Out:
# /home/ye/aif2/TinySVM-0.09

# %%
# !./configure
# Out:
# creating cache ./config.cache
# checking for a BSD compatible install... /usr/bin/install -c
# checking whether build environment is sane... yes
# checking whether make sets ${MAKE}... yes
# checking for working aclocal... found
# checking for working autoconf... found
# checking for working automake... found
# checking for working autoheader... found
# checking for working makeinfo... missing
# checking for gcc... gcc
# checking whether the C compiler (gcc  ) works... yes
# checking whether the C compiler (gcc  ) is a cross-compiler... no
# checking whether we are using GNU C... yes
# checking whether gcc accepts -g... yes
# checking for c++... c++
# checking whether the C++ compiler (c++  ) works... yes
# checking whether the C++ compiler (c++  ) is a cross-compiler... no
# checking whether we are using GNU C++... yes
# checking whether c++ accepts -g... yes
# checking how to run the C preprocessor... gcc -E
# checking whether gcc needs -traditional... no
# ...

# %%
# !make
# Out:
# make  all-recursive
# make[1]: Entering directory '/home/ye/aif2/TinySVM-0.09'
# Making all in src
# make[2]: Entering directory '/home/ye/aif2/TinySVM-0.09/src'
# /bin/sh ../libtool --mode=compile gcc -DHAVE_CONFIG_H -I. -I. -I..     -Wall -O9 -funroll-all-loops -finline -ffast-math -c getopt.c
# mkdir .libs
# gcc -DHAVE_CONFIG_H -I. -I. -I.. -Wall -O9 -funroll-all-loops -finline -ffast-math -c getopt.c  -fPIC -DPIC -o .libs/getopt.lo
# gcc -DHAVE_CONFIG_H -I. -I. -I.. -Wall -O9 -funroll-all-loops -finline -ffast-math -c getopt.c -o getopt.o >/dev/null 2>&1
# mv -f .libs/getopt.lo getopt.lo
# /bin/sh ../libtool --mode=compile gcc -DHAVE_CONFIG_H -I. -I. -I..     -Wall -O9 -funroll-all-loops -finline -ffast-math -c getopt1.c
# rm -f .libs/getopt1.lo
# gcc -DHAVE_CONFIG_H -I. -I. -I.. -Wall -O9 -funroll-all-loops -finline -ffast-math -c getopt1.c  -fPIC -DPIC -o .libs/getopt1.lo
# ...

# %% [markdown]
# ```
# ye@lst-hpc3090:~/aif2/TinySVM-0.09$ sudo make install
# [sudo] password for ye:
# Making install in src
# make[1]: Entering directory '/home/ye/aif2/TinySVM-0.09/src'
# make[2]: Entering directory '/home/ye/aif2/TinySVM-0.09/src'
# /bin/sh ../mkinstalldirs /usr/local/lib
# /bin/sh ../libtool  --mode=install /usr/bin/install -c libtinysvm.la /usr/local/lib/libtinysvm.la
# /usr/bin/install -c .libs/libtinysvm.lai /usr/local/lib/libtinysvm.la
# /usr/bin/install -c .libs/libtinysvm.a /usr/local/lib/libtinysvm.a
# ranlib /usr/local/lib/libtinysvm.a
# chmod 644 /usr/local/lib/libtinysvm.a
# PATH="$PATH:/sbin" ldconfig -n /usr/local/lib
# ----------------------------------------------------------------------
# Libraries have been installed in:
#    /usr/local/lib
#
# If you ever happen to want to link against installed libraries
# in a given directory, LIBDIR, you must either use libtool, and
# specify the full pathname of the library, or use the `-LLIBDIR'
# flag during linking and do at least one of the following:
#    - add LIBDIR to the `LD_LIBRARY_PATH' environment variable
#      during execution
#    - add LIBDIR to the `LD_RUN_PATH' environment variable
#      during linking
#    - use the `-Wl,--rpath -Wl,LIBDIR' linker flag
#    - have your system administrator add LIBDIR to `/etc/ld.so.conf'
#
# See any operating system documentation about shared libraries for
# more information, such as the ld(1) and ld.so(8) manual pages.
# ----------------------------------------------------------------------
# /bin/sh ../mkinstalldirs /usr/local/bin
#  /bin/sh ../libtool  --mode=install /usr/bin/install -c  svm_learn /usr/local/bin/svm_learn
# /usr/bin/install -c svm_learn /usr/local/bin/svm_learn
#  /bin/sh ../libtool  --mode=install /usr/bin/install -c  svm_classify /usr/local/bin/svm_classify
# /usr/bin/install -c svm_classify /usr/local/bin/svm_classify
#  /bin/sh ../libtool  --mode=install /usr/bin/install -c  svm_model /usr/local/bin/svm_model
# /usr/bin/install -c svm_model /usr/local/bin/svm_model
# /bin/sh ../mkinstalldirs /usr/local/include
#  /usr/bin/install -c -m 644 tinysvm.h /usr/local/include/tinysvm.h
# /bin/sh ../mkinstalldirs /usr/local/include/TinySVM
#  /usr/bin/install -c -m 644 model.h /usr/local/include/TinySVM/model.h
#  /usr/bin/install -c -m 644 example.h /usr/local/include/TinySVM/example.h
#  /usr/bin/install -c -m 644 base_example.h /usr/local/include/TinySVM/base_example.h
#  /usr/bin/install -c -m 644 param.h /usr/local/include/TinySVM/param.h
#  /usr/bin/install -c -m 644 misc.h /usr/local/include/TinySVM/misc.h
#  /usr/bin/install -c -m 644 kernel.h /usr/local/include/TinySVM/kernel.h
#  /usr/bin/install -c -m 644 classifier.h /usr/local/include/TinySVM/classifier.h
# make[2]: Leaving directory '/home/ye/aif2/TinySVM-0.09/src'
# make[1]: Leaving directory '/home/ye/aif2/TinySVM-0.09/src'
# Making install in tests
# make[1]: Entering directory '/home/ye/aif2/TinySVM-0.09/tests'
# make[2]: Entering directory '/home/ye/aif2/TinySVM-0.09/tests'
# make[2]: Nothing to be done for 'install-exec-am'.
# make[2]: Nothing to be done for 'install-data-am'.
# make[2]: Leaving directory '/home/ye/aif2/TinySVM-0.09/tests'
# make[1]: Leaving directory '/home/ye/aif2/TinySVM-0.09/tests'
# Making install in man
# make[1]: Entering directory '/home/ye/aif2/TinySVM-0.09/man'
# make[2]: Entering directory '/home/ye/aif2/TinySVM-0.09/man'
# make[2]: Nothing to be done for 'install-exec-am'.
# make  install-man1
# make[3]: Entering directory '/home/ye/aif2/TinySVM-0.09/man'
# /bin/sh ../mkinstalldirs /usr/local/man/man1
#  /usr/bin/install -c -m 644 ./svm_learn.1 /usr/local/man/man1/svm_learn.1
#  /usr/bin/install -c -m 644 ./svm_classify.1 /usr/local/man/man1/svm_classify.1
#  /usr/bin/install -c -m 644 ./svm_model.1 /usr/local/man/man1/svm_model.1
# make[3]: Leaving directory '/home/ye/aif2/TinySVM-0.09/man'
# make[2]: Leaving directory '/home/ye/aif2/TinySVM-0.09/man'
# make[1]: Leaving directory '/home/ye/aif2/TinySVM-0.09/man'
# Making install in doc
# make[1]: Entering directory '/home/ye/aif2/TinySVM-0.09/doc'
# make[2]: Entering directory '/home/ye/aif2/TinySVM-0.09/doc'
# make[2]: Nothing to be done for 'install-exec-am'.
# make[2]: Nothing to be done for 'install-data-am'.
# make[2]: Leaving directory '/home/ye/aif2/TinySVM-0.09/doc'
# make[1]: Leaving directory '/home/ye/aif2/TinySVM-0.09/doc'
# make[1]: Entering directory '/home/ye/aif2/TinySVM-0.09'
# make[2]: Entering directory '/home/ye/aif2/TinySVM-0.09'
# make[2]: Nothing to be done for 'install-exec-am'.
# make[2]: Nothing to be done for 'install-data-am'.
# make[2]: Leaving directory '/home/ye/aif2/TinySVM-0.09'
# make[1]: Leaving directory '/home/ye/aif2/TinySVM-0.09'
# ye@lst-hpc3090:~/aif2/TinySVM-0.09$
# ```

# %%
# !ls ./src/ -F | grep '\*$'
# Out:
# svm_classify*
# svm_learn*
# svm_model*

# %% [markdown]
# ## Data Preparation

# %%
# %pwd
# Out:
# '/home/ye/aif2/TinySVM-0.09'

# %%
# !mkdir data

# %%
# %cd /home/ye/aif2/TinySVM-0.09/data
# Out:
# /home/ye/aif2/TinySVM-0.09/data

# %%
# !cat ./prepare_iris.py
# Out:
# from sklearn.datasets import load_iris
# from sklearn.model_selection import train_test_split
#
# # 1. Load Iris dataset
# iris = load_iris()
# X, y = iris.data, iris.target
#
# # 2. Convert to Binary Classification: Class 0 (Setosa) vs. Others (-1)
# # Class 0 -> +1, Classes 1 and 2 -> -1
# binary_y = [+1 if label == 0 else -1 for label in y]
#
# # 3. Split into train (80%) and test (20%) sets
# X_train, X_test, y_train, y_test = train_test_split(
#     X, binary_y, test_size=0.2, random_state=42
# )
#
# def write_svm_file(filename, features, labels):
#     with open(filename, 'w', encoding='utf-8') as f:
#         for label, vector in zip(labels, features):
#             # TinySVM format: label index:value index:value ...
#             # Feature indices start at 1
#             feat_str = " ".join([f"{idx+1}:{val:.4f}" for idx, val in enumerate(vector)])
#             f.write(f"{label} {feat_str}\n")
#
# # 4. Write out files for TinySVM
# ...

# %%
# !time python3 prepare_iris.py
# Out:
# Preprocessing complete! Created 'iris_train.svm' and 'iris_test.svm'.
#
# real	0m0.660s
# user	0m5.598s
# sys	0m0.079s

# %%
# !wc *.svm
# Out:
#   30  150 1160 iris_test.svm
#  120  600 4640 iris_train.svm
#  150  750 5800 total

# %%
# !head iris_train.svm
# Out:
# 1 1:4.6000 2:3.6000 3:1.0000 4:0.2000
# 1 1:5.7000 2:4.4000 3:1.5000 4:0.4000
# -1 1:6.7000 2:3.1000 3:4.4000 4:1.4000
# 1 1:4.8000 2:3.4000 3:1.6000 4:0.2000
# 1 1:4.4000 2:3.2000 3:1.3000 4:0.2000
# -1 1:6.3000 2:2.5000 3:5.0000 4:1.9000
# -1 1:6.4000 2:3.2000 3:4.5000 4:1.5000
# 1 1:5.2000 2:3.5000 3:1.5000 4:0.2000
# 1 1:5.0000 2:3.6000 3:1.4000 4:0.2000
# 1 1:5.2000 2:4.1000 3:1.5000 4:0.1000

# %%
# !head iris_test.svm
# Out:
# -1 1:6.1000 2:2.8000 3:4.7000 4:1.2000
# 1 1:5.7000 2:3.8000 3:1.7000 4:0.3000
# -1 1:7.7000 2:2.6000 3:6.9000 4:2.3000
# -1 1:6.0000 2:2.9000 3:4.5000 4:1.5000
# -1 1:6.8000 2:2.8000 3:4.8000 4:1.4000
# 1 1:5.4000 2:3.4000 3:1.5000 4:0.4000
# -1 1:5.6000 2:2.9000 3:3.6000 4:1.3000
# -1 1:6.9000 2:3.1000 3:5.1000 4:2.3000
# -1 1:6.2000 2:2.2000 3:4.5000 4:1.5000
# -1 1:5.8000 2:2.7000 3:3.9000 4:1.2000

# %% [markdown]
# ## Training

# %%
# !svm_learn --help
# Out:
# TinySVM - tiny SVM package
# Copyright (C) 2000-2002 Taku Kudo, All rights reserved.
#
# Usage: svm_learn [options] training-file model-file
#
# Solver Type:
#   -l, --solver-type=INT              select type of solver.
#                                      TYPE:  0 - C-SVM (default)
#                                             1 - C-SVR
#                                             2 - One-Class-SVM (experimental)
# Kernel Parameter:
#   -t, --kernel-type=INT              select type of kernel function.
#                                      TYPE:  0 - linear      (w * x)  (default)
#                                             1 - polynomial  (s w * x + r)^d
#                                             2 - neural      tanh (s w * x + r)
#                                             3 - RBF         exp (-s * ||w-x||^2)
#                                             4 - ANOVA       (sum_i [exp(-s * ||w_i-x_i||^2)])^d
# ...

# %%
# %cd ..
# Out:
# /home/ye/aif2/TinySVM-0.09

# %%
# !mkdir model

# %%
# !time svm_learn -l 0 -c 1.0 ./data/iris_train.svm ./model/iris.model
# Out:
# TinySVM - tiny SVM package
# Copyright (C) 2000-2002 Taku Kudo, All rights reserved.
#
#    120 examples, cache size: 120
#
# Checking optimality of inactive variables  re-activated: 0
#
# Done! 11 iterations
#
# Number of SVs (BSVs)		3 (0)
# Empirical Risk:			0 (0/120)
# L1 Loss:			0
# Object value:			-0.748058
# CPU Time:			00:00:00
#
# real	0m0.004s
# user	0m0.002s
# sys	0m0.002s

# %% [markdown]
# ## Testing or Classification

# %%
# !svm_classify --help
# Out:
# TinySVM - tiny SVM package
# Copyright (C) 2000-2002 Taku Kudo, All rights reserved.
#
# Usage: svm_classify [options] test-file model-file
#
# options:
#   -V, --verbose          set verbose mode.
#   -v, --version          show the version of TinySVM and exit.
#   -h, --help             show this help and exit.

# %%
# !time svm_classify ./data/iris_test.svm ./model/iris.model
# Out:
# Accuracy:   100.00000% (30/30)
# Precision:  100.00000% (10/10)
# Recall:     100.00000% (10/10)
# System/Answer p/p p/n n/p n/n: 10 0 0 20
#
# real	0m0.004s
# user	0m0.001s
# sys	0m0.003s

# %%
# !time svm_classify ./data/iris_test.svm ./model/iris.model -V
# Out:
# -1 -2.64053
# 1 1.32654
# -1 -5.53535
# -1 -2.52237
# -1 -2.86572
# 1 1.28565
# -1 -1.50852
# -1 -3.43227
# -1 -2.89697
# -1 -1.87659
# -1 -3.22251
# 1 1.34385
# 1 1.62669
# 1 1.29117
# 1 1.55463
# -1 -2.5743
# -1 -4.12184
# -1 -1.92543
# -1 -2.46801
# -1 -4.02107
# 1 1.20583
# -1 -3.01517
# 1 1.20368
# -1 -3.97466
# -1 -4.27732
# -1 -3.57561
# -1 -4.20639
# -1 -4.17788
# 1 1.25103
# 1 1.14905
# Accuracy:   100.00000% (30/30)
# Precision:  100.00000% (10/10)
# Recall:     100.00000% (10/10)
# System/Answer p/p p/n n/p n/n: 10 0 0 20
#
# real	0m0.002s
# user	0m0.001s
# sys	0m0.001s
