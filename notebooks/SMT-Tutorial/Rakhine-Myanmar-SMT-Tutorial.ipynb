# %% [markdown]
# # Rakhine Myanmar SMT Tutorial
# Date: 19 Sept 2026
# Run by Ye Kyaw Thu, LU Lab, AI Mario, Myanmar.
# For AI Engineering (Foundational) Students, Batch-2.
#
# ## Reference Links
#
# Moses:
# [https://github.com/moses-smt/mosesdecoder](https://github.com/moses-smt/mosesdecoder)
#
# GIZA++:
# [https://github.com/moses-smt/giza-pp](https://github.com/moses-smt/giza-pp)
#
# KenLM:
# [https://github.com/kpu/kenlm](https://github.com/kpu/kenlm)
#
# Manual of Moses:
# [https://www2.statmt.org/moses/manual/manual.pdf](https://www2.statmt.org/moses/manual/manual.pdf)
#
# ChrF++:
# [https://github.com/m-popovic/chrF](https://github.com/m-popovic/chrF)
#
# ## Parallel Data Preparation

# %%
# %pwd
# Out:
# '/home/ye/exp/SMT-NMT_tutorial'

# %%
# %cd myrk
# Out:
# /home/ye/exp/SMT-NMT_tutorial/myrk

# %%
# !wget https://raw.githubusercontent.com/ye-kyaw-thu/myPar/refs/heads/master/my-rk/ver-0.1/train.my
# Out:
# --2026-09-19 13:33:09--  https://raw.githubusercontent.com/ye-kyaw-thu/myPar/refs/heads/master/my-rk/ver-0.1/train.my
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1588605 (1.5M) [text/plain]
# Saving to: ‘train.my’
#
# train.my            100%[===================>]   1.51M  --.-KB/s    in 0.02s
#
# 2026-09-19 13:33:09 (84.0 MB/s) - ‘train.my’ saved [1588605/1588605]

# %%
# !wget https://raw.githubusercontent.com/ye-kyaw-thu/myPar/refs/heads/master/my-rk/ver-0.1/train.rk
# Out:
# --2026-09-19 13:33:22--  https://raw.githubusercontent.com/ye-kyaw-thu/myPar/refs/heads/master/my-rk/ver-0.1/train.rk
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.111.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1567486 (1.5M) [text/plain]
# Saving to: ‘train.rk’
#
# train.rk            100%[===================>]   1.49M  --.-KB/s    in 0.1s
#
# 2026-09-19 13:33:23 (11.5 MB/s) - ‘train.rk’ saved [1567486/1567486]

# %%
# !wget https://raw.githubusercontent.com/ye-kyaw-thu/myPar/refs/heads/master/my-rk/ver-0.1/dev.my
# Out:
# --2026-09-19 13:34:04--  https://raw.githubusercontent.com/ye-kyaw-thu/myPar/refs/heads/master/my-rk/ver-0.1/dev.my
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 286978 (280K) [text/plain]
# Saving to: ‘dev.my’
#
# dev.my              100%[===================>] 280.25K   403KB/s    in 0.7s
#
# 2026-09-19 13:34:06 (403 KB/s) - ‘dev.my’ saved [286978/286978]

# %%
# !wget https://raw.githubusercontent.com/ye-kyaw-thu/myPar/refs/heads/master/my-rk/ver-0.1/dev.rk
# Out:
# --2026-09-19 13:34:15--  https://raw.githubusercontent.com/ye-kyaw-thu/myPar/refs/heads/master/my-rk/ver-0.1/dev.rk
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 282388 (276K) [text/plain]
# Saving to: ‘dev.rk’
#
# dev.rk              100%[===================>] 275.77K  --.-KB/s    in 0.007s
#
# 2026-09-19 13:34:15 (36.8 MB/s) - ‘dev.rk’ saved [282388/282388]

# %%
# !wget https://raw.githubusercontent.com/ye-kyaw-thu/myPar/refs/heads/master/my-rk/ver-0.1/test.my
# Out:
# --2026-09-19 13:34:21--  https://raw.githubusercontent.com/ye-kyaw-thu/myPar/refs/heads/master/my-rk/ver-0.1/test.my
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.111.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 208710 (204K) [text/plain]
# Saving to: ‘test.my’
#
# test.my             100%[===================>] 203.82K  --.-KB/s    in 0.01s
#
# 2026-09-19 13:34:22 (16.8 MB/s) - ‘test.my’ saved [208710/208710]

# %%
# !wget https://raw.githubusercontent.com/ye-kyaw-thu/myPar/refs/heads/master/my-rk/ver-0.1/test.rk
# Out:
# --2026-09-19 13:34:29--  https://raw.githubusercontent.com/ye-kyaw-thu/myPar/refs/heads/master/my-rk/ver-0.1/test.rk
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.111.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 205385 (201K) [text/plain]
# Saving to: ‘test.rk’
#
# test.rk             100%[===================>] 200.57K  --.-KB/s    in 0.006s
#
# 2026-09-19 13:34:29 (34.3 MB/s) - ‘test.rk’ saved [205385/205385]

# %% [markdown]
# ## Confirmation on Downloaded Data

# %%
# !head *.my
# Out:
# ==> dev.my <==
# ကျွန်တော် မနက်ဖြန် ကား အသစ် တွေ သွား ကြည့် မလို့ ။
# မင်း ဘာ တွေ သတင်းပေး မှာလဲ ။
# အကြံဉာဏ် ကောင်းတွေ လိုချင် လား ။
# မင်း ဘာ တွေ သယ် နေတာလဲ ။
# မင်း ငါ့ကို မ မုန်း ခဲ့ဘူး နော် ၊ မုန်း ခဲ့သလား ။
# အပြင်မှာ မှောင်နေ သေးတယ် ။
# ကျွန်တော် ခင်ဗျားကို အိမ် လိုက်ပို့ပေးမယ် ။
# မင်း ကတိမပျက် ပါဘူး ။
# ဘယ်သူ အလုပ် လာလုပ် မှာလဲ ။
# ကျွန်တော်လည်း အဲဒီလို ထင်တာပဲ ။
#
# ==> test.my <==
# သူ အမှန်အတိုင်း မ ကျိန်ဆို ရဲ ဘူးလား ။
# ကျွန်တော်သာဆို ပြန်ပေး လိုက်မှာ ။
# ဆူပြီးတဲ့ ရေကို သောက် သင့်တယ် ။
# ခင်ဗျား မေးစရာ မ လို ဘူး ။
# သူမ ကို သူ တကယ် မ မြတ်နိုး ခဲ့ပါ ။
# ကိုယ် မင်း ကို နားလည် ပါတယ် ။
# ငါ အလုပ် မ ပြီး သေး ဘူး ။
# ကျွန်တော် ဘတ်စ်ကား အတွက် အကြွေ အချို့ လို ချင်လို့ပါ ။
# မိုး  ချက်ချင်း ရွာတဲ့အခါ သူရို့ဘာတွေ လုပ် နေတာလဲ ။
# မင်း တောင်တွေကို တက်နေ ကျလား ။
#
# ==> train.my <==
# မင်း အဲ့ဒါ ကို အခြား တစ်ခုနဲ့ မ ချိတ် ဘူးလား ။
# သူမ ဘယ်သူ့ကိုမှ မ မှတ်မိတော့ဘူး ။
# အဲ့ဒါ ကျွန်တော်တို့ အတွက် ခက်ခဲတယ် ။
# ခင်ဗျား ပြောခဲ့ သလို ကျွန်တော် ရှင်းပြ ခဲ့တယ် ။
# ...

# %%
# !head *.rk
# Out:
# ==> dev.rk <==
# ကျွန်တော် နက်ဖန် ကား အသစ် တိ လား ကြည့် ဖို့လို့ ။
# မင်း ဇာ တိ သတင်းပီး ဖို့လေး။
# အကြံဉာဏ် ကောင်းတိ လိုချင် လား ။
# မင်း ဇာ တိ သယ် နီစွာလေး ။
# မင်း ငါ့ကို မ မုန်း ခပါ  နောက် ၊ မုန်း ခပါလား ။
# အပြင်မှာ မှောင်နီ သီးရေ ။
# ကျွန်တော် ခင်ဗျားကို အိမ် လိုက်ပို့ပီးမေ ။
# မင်း ကတိမပျက် ပါ ။
# ဇာသူ အလုပ် လာလုပ် ဖို့လေး။
# ငါလည်း ယင်းပိုင် ထင်ရေ ။
#
# ==> test.rk <==
# သူ အမှန်အတိုင်း မ ကျိန်ဆို ရဲ  ပါလား။
# ကျွန်တော်ဆိုကေ ပြန်ပီး လိုက်ဖို့ ။
# ဆူပြီး ရီကို သောက် သင့်ရေ။
# မင်း မိန်းစရာ မ လို ပါ ။
# ထိုမချေ ကို သူ အမှန် မ မြတ်နိုး ခပါ ။
# ကိုယ် မင်း ကို နားလည် ပါရေ။
# ငါ အလုပ် မ ပြီး သိ ပါ ။
# ငါ ဘတ်စ်ကား စီးဖို့ အတွက် အကြွီ လို ချင်ရေ ။
# မိုး  ချက်ချင်း ရွာရေအခါ သူရို့ ဇာတိ လုပ် နီစွာ ။
# မင်း တောင်တိကို တက်နီ ကျလား ။
#
# ==> train.rk <==
# မင်း ယင်းချင့် ကို အခြား တစ်ခုနန့်  မ ချိတ် ပါလား ။
# ထိုမချေ   တစ်ယောက်လေ့  မ မှတ်မိပါယာ ။
# ယင်းချင့် ကျွန်တော်  ရို့ အတွက် ခက်ခ ရေ ။
# မင်း ပြောခ ရေပိုင် ကျွန်တော် ယှင်းပြ ခရေ ။
# သူ့ကို ထိန်းဖို့ မင်း ရာ တတ်နိုင်ရေ။
# ...

# %%
# !wc *.my
# Out:
#    2485   17104  286978 dev.my
#    1812   12478  208710 test.my
#   14076   95738 1588605 train.my
#   18373  125320 2084293 total

# %%
# !wc *.rk
# Out:
#    2485   16795  282388 dev.rk
#    1812   12275  205385 test.rk
#   14076   93957 1567486 train.rk
#   18373  123027 2055259 total

# %% [markdown]
# ## Data Cleaning

# %%
# %pwd
# Out:
# '/home/ye/exp/SMT-NMT_tutorial/myrk'

# %%
# %cd ..
# Out:
# /home/ye/exp/SMT-NMT_tutorial

# %%
# %cd tool
# Out:
# /home/ye/exp/SMT-NMT_tutorial/tool

# %%
# !ls
# Out:
# char-segmentation.sh  correct_my_punc.py  sylbreak.py
# clean-space.pl	      print-codepoint.pl

# %%
# !cat clean-space.pl
# Out:
# #!/usr/bin/env perl
#
# # cleaning heading spaces, training spaces, double spaces and blank lines
# # Ye Kyaw Thu, AI Lab., OPU, Japan
# #
# # Preparation for KNLP 2016 conf. paper
# # e.g. $ perl clean-space.pl <input-file>
#
# use strict;
# use warnings;
# use utf8;
#
# binmode(STDIN, ":utf8");
# binmode(STDOUT, ":utf8");
# binmode(STDERR, ":utf8");
#
# open (my $inputFILE,"<:encoding(utf8)", $ARGV[0]) or die "Couldn't open input file $ARGV[0]!, $!\n";
#
# while (!eof($inputFILE)) {
#
#     my $line = <$inputFILE>;
#     if (($line ne '') & ($line !~ /^ *$/)) {
#         chomp($line);
#         $line =~ s/^\s+|\s+$//g;
#         $line =~ s/ +/ /g;
#
#         print "$line\n";
#     }
#
# }
#
# close ($inputFILE);

# %%
# %cd /home/ye/exp/SMT-NMT_tutorial/myrk
# Out:
# /home/ye/exp/SMT-NMT_tutorial/myrk

# %%
# %mkdir clean

# %%
# !perl ../tool/clean-space.pl ./train.my > ./clean/train.my

# %%
# !perl ../tool/clean-space.pl ./train.rk > ./clean/train.rk

# %%
# !perl ../tool/clean-space.pl ./dev.my > ./clean/dev.my

# %%
# !perl ../tool/clean-space.pl ./dev.rk > ./clean/dev.rk

# %%
# !perl ../tool/clean-space.pl ./test.my > ./clean/test.my

# %%
# !perl ../tool/clean-space.pl ./test.rk > ./clean/test.rk

# %%
# !wc ./*.my
# Out:
#    2485   17104  286978 ./dev.my
#    1812   12478  208710 ./test.my
#   14076   95738 1588605 ./train.my
#   18373  125320 2084293 total

# %%
# !wc ./clean/*.my
# Out:
#    2484   17104  286906 ./clean/dev.my
#    1811   12478  208683 ./clean/test.my
#   14069   95738 1588323 ./clean/train.my
#   18364  125320 2083912 total

# %%
# !wc ./*.rk
# Out:
#    2485   16795  282388 ./dev.rk
#    1812   12275  205385 ./test.rk
#   14076   93957 1567486 ./train.rk
#   18373  123027 2055259 total

# %%
# !wc ./clean/*.rk
# Out:
#    2485   16795  281654 ./clean/dev.rk
#    1811   12275  204836 ./clean/test.rk
#   14070   93957 1563248 ./clean/train.rk
#   18366  123027 2049738 total

# %%
# !paste ./clean/train.my ./clean/train.rk | tail
# Out:
# ​စောဒက မ တက် တဲ့အတွက် ငါ ကျေနပ်တယ် လို့ မ ထင်နဲ့ ။	ယင်း ကို သူရို့ ခိုး ဖို့ မဟုတ်ပါ ။
# ဒီမှာ မ နေ နဲ့ ။	စောဒက မ တက် ရေအတွက် ငါ ကျေနပ်ရေ လို့ မ ထင်ကေ ။
# တစ်ခါတစ်ခါ စက် မ နိုးဘူး ။	ဒေမာ မ နီ ကေ ။
# ကျွန်တော့် ဘဝ မှာ နိုင်ငံရဲ့ အကြီးမားဆုံး စာရိတ္တပိုင်း ဆုံးရှုံးမှုက အခြေခံကျတဲ့ ကျင့်ဝတ် တစ်ခုကို ကျွန်တော်တို့က မ လိုက်နာ သေးလို့ပဲ လို့ ထင်ပါတယ် ။	တစ်ခါတစ်ခါ စက် မ နိုးပါ ။
# ဘာပဲဖြစ်ဖြစ် မင်း ကြိုက်သလိုသာ လုပ်ပါ ။	ကျွန်တော့် ဘဝ မာ နိုင်ငံရဲ့ အကြီးမားဆုံး စာရိတ္တပိုင်း ဆုံးရှုံးမှုက အခြီခံကျရေ ကျင့်ဝတ် တစ်ခုကို ကျွန်တော်ရို့က မ လိုက်နာ သီလို့ ထင် ပါရေ ။
# ဒီလို ပြောတာ ကျေးဇူးတင်ပါတယ် ။	ဇာဘင်ဖြစ်ဖြစ် မင်း ကြိုက်သလိုသာ လုပ်ပါ ။
# ဒါ သိပ်လှတဲ့ ကားပါလား ။	ဒေပိုင် ပြောစွာ ကျေးဇူးအများကြီးတင်ပါရေ ။
# ဒီ စမ်းသပ်ချက်များက ဘယ်လိုမှ အသုံး မ တည့်ဘူး ။	ဒေချင့် ကကောင်း လှရေ ကားပါ ။
# သူ ကျွန်တော် နဲ့ သဘောမတူ ဘူး ။	ဒီ စမ်းသပ်ချက်တိက တစ်ခုပိုင်လည်း အသုံး မ တည့် ။
# 	သူ ကျွန်တော် နန့် သဘောမတူ ပါ။

# %%
# !file *.*
# Out:
# dev.my:   Unicode text, UTF-8 text
# dev.rk:   Unicode text, UTF-8 text
# test.my:  Unicode text, UTF-8 text
# test.rk:  Unicode text, UTF-8 text
# train.my: Unicode text, UTF-8 text
# train.rk: Unicode text, UTF-8 text

# %%
# %pwd
# Out:
# '/home/ye/exp/SMT-NMT_tutorial/myrk'

# %%
# %cd ../tool/
# Out:
# /home/ye/exp/SMT-NMT_tutorial/tool

# %%
# !wget https://raw.githubusercontent.com/ye-kyaw-thu/tools/refs/heads/master/perl/print-blank-lines.pl
# Out:
# --2026-09-19 14:13:21--  https://raw.githubusercontent.com/ye-kyaw-thu/tools/refs/heads/master/perl/print-blank-lines.pl
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 595 [text/plain]
# Saving to: ‘print-blank-lines.pl’
#
# print-blank-lines.p 100%[===================>]     595  --.-KB/s    in 0s
#
# 2026-09-19 14:13:22 (33.2 MB/s) - ‘print-blank-lines.pl’ saved [595/595]

# %%
# !cat ./print-blank-lines.pl
# Out:
# #!/usr/bin/env perl
#
# # for printing blank lines, space only lines, tab only lines
# # Ye Kyaw Thu, LST, NECTEC, Thailand
# #
# # e.g. $ perl print-blank-lines.pl <input-file>
#
# use strict;
# use warnings;
# use utf8;
#
# binmode(STDIN, ":utf8");
# binmode(STDOUT, ":utf8");
# binmode(STDERR, ":utf8");
#
# open (my $inputFILE,"<:encoding(utf8)", $ARGV[0]) or die "Couldn't open input file $ARGV[0]!, $!\n";
#
# my $line_no = 1;
# while (!eof($inputFILE)) {
#
#     my $line = <$inputFILE>;
#     if (($line eq '') || ($line =~ /^[ |\t]*$/)) {
#         print "$line_no\t$line";
#     }
#     $line_no++;
# }
#
# close ($inputFILE);

# %%
# %cd /home/ye/exp/SMT-NMT_tutorial/myrk
# Out:
# /home/ye/exp/SMT-NMT_tutorial/myrk

# %%
# !ls
# Out:
# clean  dev.my  dev.rk  test.my	test.rk  train.my  train.rk

# %%
# !perl ../tool/print-blank-lines.pl ./train.my
# Out:
# 3733
# 7636
# 9253
# 10118
# 10828
# 11919
# 13223

# %%
# !perl ../tool/print-blank-lines.pl ./train.rk
# Out:
# 115
# 7320
# 10041
# 10118
# 11919
# 13223

# %%
# !perl ../tool/print-blank-lines.pl ./dev.my
# Out:
# 350

# %%
# !perl ../tool/print-blank-lines.pl ./dev.rk

# %%
# !perl ../tool/print-blank-lines.pl ./test.my
# Out:
# 906

# %%
# !perl ../tool/print-blank-lines.pl ./test.rk
# Out:
# 906

# %% [markdown]
# ## Solution

# %%
# !paste --help
# Out:
# Usage: paste [OPTION]... [FILE]...
# Write lines consisting of the sequentially corresponding lines from
# each FILE, separated by TABs, to standard output.
#
# With no FILE, or when FILE is -, read standard input.
#
# Mandatory arguments to long options are mandatory for short options too.
#   -d, --delimiters=LIST   reuse characters from LIST instead of TABs
#   -s, --serial            paste one file at a time instead of in parallel
#   -z, --zero-terminated    line delimiter is NUL, not newline
#       --help        display this help and exit
#       --version     output version information and exit
#
# GNU coreutils online help: <https://www.gnu.org/software/coreutils/>
# Full documentation <https://www.gnu.org/software/coreutils/paste>
# or available locally via: info '(coreutils) paste invocation'

# %%
# !paste train.my train.rk > train.myrk

# %%
# !paste dev.my dev.rk > dev.myrk

# %%
# !paste test.my test.rk > test.myrk

# %%
# !sed -n '3733,3735p' ./train.myrk
# Out:
#  	မင်း ဇာ တိ ဖြည့် နီစွာလေး ။
# ဟိုမှာ မင်း မြင်နေရတဲ့ သစ်ပင် အတိုင်း အတိအကျပဲ ကြီးမားတဲ့ ကျောက်တောင် ပေါ်မှာ ပေါက်နေတဲ့ ထင်းရှူးပင် ကြီး ရှိနေတယ် လို့ မြင်ယောင်ကြည့်လိုက် ။	ဟိုမာ မင်း မြင်နီရရေ သစ်ပင် အတိုင်း အတိအကျပိုင် ကျောက်တောင်ကြီးမာ ပေါက်နီရေ ထင်းရှူးပင် ကြီး ရှိနေတယ် လို့ မြင်ယောင်ကြည့်လိုက် ။
# အဲ့ဒါကို သူကိုယ်တိုင် ညွှန်ကြား ခဲ့တာပါ ။	ယင်းချင့်ကို သူကိုယ်တိုင် ညွှန်ကြား ခစွာပါ ။

# %% [markdown]
# **We did manual cleaning on local machine!**

# %%
# !wc ./clean/*.myrk
# Out:
#    2484   33893  569250 ./clean/dev.myrk
#    1811   24753  414093 ./clean/test.myrk
#   14066  189640 3155298 ./clean/train.myrk
#   18361  248286 4138641 total

# %%
# !wc *.myrk
# Out:
#    2485   33899  569366 dev.myrk
#    1812   24753  414095 test.myrk
#   14076  189695 3156091 train.myrk
#   18373  248347 4139552 total

# %%
# %cd clean
# Out:
# /home/ye/exp/SMT-NMT_tutorial/myrk/clean

# %%
# !ls
# Out:
# dev.my	  dev.rk   test.myrk  train.my	  train.rk
# dev.myrk  test.my  test.rk    train.myrk

# %%
# !mkdir err-file

# %%
# !mv *.my ./err-file

# %%
# !mv *.rk ./err-file

# %%
# !ls
# Out:
# dev.myrk  err-file  test.myrk  train.myrk

# %%
# !cut -f1 ./train.myrk > train.my

# %%
# !cut -f2 ./train.myrk > train.rk

# %%
# !cut -f1 ./dev.myrk > dev.my

# %%
# !cut -f2 ./dev.myrk > dev.rk

# %%
# !cut -f1 ./test.myrk > test.my

# %%
# !cut -f2 ./test.myrk > test.rk

# %%
# !wc *.my
# Out:
#    2484   17104  286976 dev.my
#    1811   12478  208709 test.my
#   14066   95720 1588279 train.my
#   18361  125302 2083964 total

# %%
# !wc *.rk
# Out:
#    2484   16789  282274 dev.rk
#    1811   12275  205384 test.rk
#   14066   93920 1567019 train.rk
#   18361  122984 2054677 total

# %%
# %cd ../../tool/
# Out:
# /home/ye/exp/SMT-NMT_tutorial/tool

# %%
# !wget https://raw.githubusercontent.com/ye-kyaw-thu/tools/refs/heads/master/perl/clean-punctuation.pl
# Out:
# --2026-09-19 14:48:08--  https://raw.githubusercontent.com/ye-kyaw-thu/tools/refs/heads/master/perl/clean-punctuation.pl
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1049 (1.0K) [text/plain]
# Saving to: ‘clean-punctuation.pl’
#
# clean-punctuation.p 100%[===================>]   1.02K  --.-KB/s    in 0s
#
# 2026-09-19 14:48:08 (53.9 MB/s) - ‘clean-punctuation.pl’ saved [1049/1049]

# %%
# !cat clean-punctuation.pl
# Out:
# #!/usr/bin/env perl
#
# # cleaning punctuation characters for Burmese and other languages of Myanmar with their own characters
# # Ye Kyaw Thu, Affiliated Professor, IDRI, CADT, Cambodia
# # Note: We are removing frequently used punctuation symbols and not including ၏, ၍
# # Note: Consider for using normalize-punctuation.perl (from moses scripts) before running this perl script.
# # Preparation for giving a lecture at Mahidol University
# # Last updated: 22 May 2022
# # How to use:
# # e.g. $ perl clean-punctuation.pl <input-file>
#
# use strict;
# use warnings;
# use utf8;
#
# binmode(STDIN, ":utf8");
# binmode(STDOUT, ":utf8");
# binmode(STDERR, ":utf8");
#
# open (my $inputFILE,"<:encoding(utf8)", $ARGV[0]) or die "Couldn't open input file $ARGV[0]!, $!\n";
#
# while (!eof($inputFILE)) {
#     my $line = <$inputFILE>;
#     if (($line ne '') & ($line !~ /^ *$/)) {
#         chomp($line);
#         $line =~ s/၊|။|-|\(|\)|\[|\]|\/|\\|\!|\?|,|\"//g;
# ...

# %%
# %cd /home/ye/exp/SMT-NMT_tutorial/myrk/clean
# Out:
# /home/ye/exp/SMT-NMT_tutorial/myrk/clean

# %%
# !tail *.my
# Out:
# ==> dev.my <==
# ငါ့ အတွက် ချက်ပြုတ် ရတာ အဆင်ပြေပါတယ် ။
# မှာထားတာတွေ ဖျက်ပေးပါ ။
# မင်း ဘာ တွေ ခူး နေတာလဲ ။
# မင်း ကိုယ့်ကို ကြည့် ပါဦး ။
# ကျွန်တော့်မှာ မျက်စေ့ နှစ်လုံး နှင့် နှာခေါင်း တစ်ခု ရှိ တယ် ။
# သွေး ပေါင်ချိန် ကို ထိန်းထား ဖို့ ဆရာဝန်က ကျွန်တော့် ကို ပြော ခဲ့တယ် ။
# သူတို့ လုပ်ငန်း ဖြုတ် တော့မယ်လေ ။
# ကိုယ် ဒီနေ့ စာ အစောင် သုံးဆယ် ရိုက် ခဲ့ရတယ် ။
# ကိုယ် သနား သလို သနားပါ ။
# ခင်ဗျားတို့ ကုမ္ပဏီမှာ ဘာ ထုတ်လုပ် သလဲ ။
#
# ==> test.my <==
# အဲ့ဒီ ပြဿနာ ကို မ စစ်ဆေး ခဲ့ဘူးလား ။
# မင်း သူငယ်ချင်းတွေ ဘယ် အချိန် လာ ကြ မှာလဲ ။
# ခင်ဗျား တစ်ရက် နှစ်ရက် အလုပ်မဆင်းဘဲ အနားယူ သင့်တယ် ။
# အိုကေပါတယ် ၊ မင်းရော ။
# မင်း စာကို ထည့်ခဲ့တာ ငါ မှတ်မိ ပါတယ် ။
# မင်းအတွက် တကယ် နွေးထွေးတဲ့ မွေးနေ့ ဖြစ်ဖို့ ဆုတောင်းပေး ပါတယ် ။
# ခင်ဗျား ဘာ လုပ် မှာလဲ ။
# အခု ကျွန်တော့် အဖွား တရားထိုင် နေတာကြောင့် ကလေးတွေ တိတ်တိတ် နေစေချင်တယ် ။
# သူမ အဲ့ဒါ ကို သဘောတူ သလား ။
# အခြေအနေ က လုံးဝ ထိန်းမနိုင်သိမ်းမရ ဖြစ် နေပြီ ။
#
# ==> train.my <==
# အဲ့ဒါကို သူတို့ ခိုး မှာ မဟုတ်ဘူး ။
# ...

# %%
# !perl ../../tool/clean-punctuation.pl ./train.my > train.my.rmpun

# %%
# !perl ../../tool/clean-punctuation.pl ./train.rk > train.rk.rmpun

# %%
# !perl ../../tool/clean-punctuation.pl ./dev.my > dev.my.rmpun

# %%
# !perl ../../tool/clean-punctuation.pl ./dev.rk > dev.rk.rmpun

# %%
# !perl ../../tool/clean-punctuation.pl ./test.my > test.my.rmpun

# %%
# !perl ../../tool/clean-punctuation.pl ./test.rk > test.rk.rmpun

# %%
# !wc *.my.rmpun
# Out:
#    2484   14503  276475 dev.my.rmpun
#    1811   10593  201124 test.my.rmpun
#   14066   81052 1529127 train.my.rmpun
#   18361  106148 2006726 total

# %%
# !wc *.rk.rmpun
# Out:
#    2484   14558  271516 dev.rk.rmpun
#    1811   10657  197567 test.rk.rmpun
#   14066   81420 1506223 train.rk.rmpun
#   18361  106635 1975306 total

# %%
# !head *.my.rmpun
# Out:
# ==> dev.my.rmpun <==
# ကျွန်တော် မနက်ဖြန် ကား အသစ် တွေ သွား ကြည့် မလို့
# မင်း ဘာ တွေ သတင်းပေး မှာလဲ
# အကြံဉာဏ် ကောင်းတွေ လိုချင် လား
# မင်း ဘာ တွေ သယ် နေတာလဲ
# မင်း ငါ့ကို မ မုန်း ခဲ့ဘူး နော် မုန်း ခဲ့သလား
# အပြင်မှာ မှောင်နေ သေးတယ်
# ကျွန်တော် ခင်ဗျားကို အိမ် လိုက်ပို့ပေးမယ်
# မင်း ကတိမပျက် ပါဘူး
# ဘယ်သူ အလုပ် လာလုပ် မှာလဲ
# ကျွန်တော်လည်း အဲဒီလို ထင်တာပဲ
#
# ==> test.my.rmpun <==
# သူ အမှန်အတိုင်း မ ကျိန်ဆို ရဲ ဘူးလား
# ကျွန်တော်သာဆို ပြန်ပေး လိုက်မှာ
# ဆူပြီးတဲ့ ရေကို သောက် သင့်တယ်
# ခင်ဗျား မေးစရာ မ လို ဘူး
# သူမ ကို သူ တကယ် မ မြတ်နိုး ခဲ့ပါ
# ကိုယ် မင်း ကို နားလည် ပါတယ်
# ငါ အလုပ် မ ပြီး သေး ဘူး
# ကျွန်တော် ဘတ်စ်ကား အတွက် အကြွေ အချို့ လို ချင်လို့ပါ
# မိုး ချက်ချင်း ရွာတဲ့အခါ သူရို့ဘာတွေ လုပ် နေတာလဲ
# မင်း တောင်တွေကို တက်နေ ကျလား
#
# ==> train.my.rmpun <==
# မင်း အဲ့ဒါ ကို အခြား တစ်ခုနဲ့ မ ချိတ် ဘူးလား
# သူမ ဘယ်သူ့ကိုမှ မ မှတ်မိတော့ဘူး
# အဲ့ဒါ ကျွန်တော်တို့ အတွက် ခက်ခဲတယ်
# ခင်ဗျား ပြောခဲ့ သလို ကျွန်တော် ရှင်းပြ ခဲ့တယ်
# သူ့ကို ထိန်းဖို့ မင်း ပဲ တတ်နိုင်တယ်
# ...

# %%
# !head *.rk.rmpun
# Out:
# ==> dev.rk.rmpun <==
# ကျွန်တော် နက်ဖန် ကား အသစ် တိ လား ကြည့် ဖို့လို့
# မင်း ဇာ တိ သတင်းပီး ဖို့လေး
# အကြံဉာဏ် ကောင်းတိ လိုချင် လား
# မင်း ဇာ တိ သယ် နီစွာလေး
# မင်း ငါ့ကို မ မုန်း ခပါ နောက် မုန်း ခပါလား
# အပြင်မှာ မှောင်နီ သီးရေ
# ကျွန်တော် ခင်ဗျားကို အိမ် လိုက်ပို့ပီးမေ
# မင်း ကတိမပျက် ပါ
# ဇာသူ အလုပ် လာလုပ် ဖို့လေး
# ငါလည်း ယင်းပိုင် ထင်ရေ
#
# ==> test.rk.rmpun <==
# သူ အမှန်အတိုင်း မ ကျိန်ဆို ရဲ ပါလား
# ကျွန်တော်ဆိုကေ ပြန်ပီး လိုက်ဖို့
# ဆူပြီး ရီကို သောက် သင့်ရေ
# မင်း မိန်းစရာ မ လို ပါ
# ထိုမချေ ကို သူ အမှန် မ မြတ်နိုး ခပါ
# ကိုယ် မင်း ကို နားလည် ပါရေ
# ငါ အလုပ် မ ပြီး သိ ပါ
# ငါ ဘတ်စ်ကား စီးဖို့ အတွက် အကြွီ လို ချင်ရေ
# မိုး ချက်ချင်း ရွာရေအခါ သူရို့ ဇာတိ လုပ် နီစွာ
# မင်း တောင်တိကို တက်နီ ကျလား
#
# ==> train.rk.rmpun <==
# မင်း ယင်းချင့် ကို အခြား တစ်ခုနန့် မ ချိတ် ပါလား
# ထိုမချေ တစ်ယောက်လေ့ မ မှတ်မိပါယာ
# ယင်းချင့် ကျွန်တော် ရို့ အတွက် ခက်ခ ရေ
# မင်း ပြောခ ရေပိုင် ကျွန်တော် ယှင်းပြ ခရေ
# သူ့ကို ထိန်းဖို့ မင်း ရာ တတ်နိုင်ရေ
# ယင်းချင့် ကို ငါ တက်နင်း မိလား လာ
# ...

# %%
# %pwd
# Out:
# '/home/ye/exp/SMT-NMT_tutorial/myrk/clean'

# %%
# !ls
# Out:
# dev.my	      dev.rk.rmpun  test.my.rmpun    train.my	     train.rk.rmpun
# dev.myrk      err-file	    test.rk	     train.myrk
# dev.my.rmpun  test.my	    test.rk.rmpun    train.my.rmpun
# dev.rk	      test.myrk     train.dev.rmpun  train.rk

# %%
# %mkdir final

# %%
# !cp *.rmpun ./final

# %%
# %cd final
# Out:
# /home/ye/exp/SMT-NMT_tutorial/myrk/clean/final

# %%
# !ls
# Out:
# dev.my.rmpun  test.my.rmpun  train.dev.rmpun  train.rk.rmpun
# dev.rk.rmpun  test.rk.rmpun  train.my.rmpun

# %%
# !mv train.my.rmpun train.my

# %%
# !mv dev.my.rmpun dev.my

# %%
# !mv test.my.rmpun test.my

# %%
# !mv train.rk.rmpun train.rk

# %%
# !mv dev.rk.rmpun dev.rk

# %%
# !mv test.rk.rmpun test.rk

# %%
# !wc *
# Out:
#    2484   14503  276475 dev.my
#    2484   14558  271516 dev.rk
#    1811   10593  201124 test.my
#    1811   10657  197567 test.rk
#    2484   14503  276475 train.dev.rmpun
#   14066   81052 1529127 train.my
#   14066   81420 1506223 train.rk
#   39206  227286 4258507 total

# %%
# !rm train.dev.rmpun

# %%
# !ls *
# Out:
# dev.my	dev.rk	test.my  test.rk  train.my  train.rk

# %%
# !tail -n 3 *.my
# Out:
# ==> dev.my <==
# ကိုယ် ဒီနေ့ စာ အစောင် သုံးဆယ် ရိုက် ခဲ့ရတယ်
# ကိုယ် သနား သလို သနားပါ
# ခင်ဗျားတို့ ကုမ္ပဏီမှာ ဘာ ထုတ်လုပ် သလဲ
#
# ==> test.my <==
# အခု ကျွန်တော့် အဖွား တရားထိုင် နေတာကြောင့် ကလေးတွေ တိတ်တိတ် နေစေချင်တယ်
# သူမ အဲ့ဒါ ကို သဘောတူ သလား
# အခြေအနေ က လုံးဝ ထိန်းမနိုင်သိမ်းမရ ဖြစ် နေပြီ
#
# ==> train.my <==
# ဒါ သိပ်လှတဲ့ ကားပါလား
# ဒီ စမ်းသပ်ချက်များက ဘယ်လိုမှ အသုံး မ တည့်ဘူး
# သူ ကျွန်တော် နဲ့ သဘောမတူ ဘူး

# %%
# !tail -n 3 *.rk
# Out:
# ==> dev.rk <==
# ကိုယ် ဒေနိ စာ အစောင် သုံးဆယ် ရိုက် ခရေ
# ကိုယ် သနား ရေပိုင် သနားပါ
# မင်းရို့ ကုမ္ပဏီမှာ ဇာ ထုတ်လုပ် လေ
#
# ==> test.rk <==
# အခု ကျွန်တော့် အဘောင်မ တရားထိုင် နီရေအတွက် အချေတိ တိတ်တိတ် နီစီချင်ရေ
# ထိုမချေ ယင်းချင့် ကို သဘောတူ ပါလား
# အခြီအနီ က လုံးဝ ထိန်းမနိုင်သိမ်းမရ ဖြစ် နီဗျာယ်
#
# ==> train.rk <==
# ဒေချင့် ကကောင်း လှရေ ကားပါ
# ဒီ စမ်းသပ်ချက်တိက တစ်ခုပိုင်လည်း အသုံး မ တည့်
# သူ ကျွန်တော် နန့် သဘောမတူ ပါ

# %% [markdown]
# ## Prepare SGM Files for Test-Set

# %%
# %pwd
# Out:
# '/home/ye/exp/SMT-NMT_tutorial/myrk/clean/final'

# %%
# !mkdir test-sgm

# %%
# %cd test-sgm
# Out:
# /home/ye/exp/SMT-NMT_tutorial/myrk/clean/final/test-sgm

# %%
# !cp /home/ye/exp/SMT-NMT_tutorial/clean-data/test-sgm/*.pl .

# %%
# !cat generate_sgms.pl
# Out:
# #!/usr/bin/perl
# use strict;
#
# # written by Ye, NECTEC
# # for MTRSS, YTU, Myanmar
#
# my @langs;
#
# #foreach my $trainFile ( </home/ros/experiment/my-rk/data/train.[a-z][a-z]> )
# foreach my $trainFile ( <../train.[a-z][a-z]> )
# {
#         $trainFile =~ m/train.([a-z][a-z])/;
#         push @langs, $1;
# }
#
# foreach my $lang (@langs)
# {
#     `perl ./ref2sgm.pl $lang > test.$lang.ref.sgm`;
#     `perl ./src2sgm.pl $lang > test.$lang.src.sgm`;
# }

# %%
# !cat src2sgm.pl
# Out:
# #!/usr/bin/perl
# use strict;
#
# # written by Ye, NECTEC
# # for MTRSS, YTU, Myanmar
#
# my $src = shift;
#
# print "<srcset setid=\"Rakhine-Myanmar_data\" srclang=\"any\">\n";
# print "<doc docid=\"none\" genre=\"1811\" origlang=\"$src\">\n";
#
# #open FILE, "/home/ros/experiment/my-rk/data/test.$src" or die;
# open FILE, "../test.$src" or die;
#
# my $id=1;
#
# while( <FILE> )
# {
# 	chomp;
#
# 	print "<seg id=\"$id\">$_ </seg>\n";
# 	$id++;
# }
#
# print "</doc>\n</srcset>\n";

# %%
# !cat ref2sgm.pl
# Out:
# #!/usr/bin/perl
# use strict;
#
# # written by Ye, NECTEC
# # for MTRSS, YTU, Myanmar
#
# my $trg = shift;
#
# #print "<refset trglang=\"$trg\" setid=\"sl_data\" srclang=\"any\">\n";
# print "<refset trglang=\"$trg\" setid=\"Rakhine-Myanmar_data\" srclang=\"any\">\n";
# print "<doc sysid=\"ref\" docid=\"none\" genre=\"1811\" origlang=\"any\">\n";
#
# #open FILE, "/home/ros/experiment/my-rk/data/test.$trg" or die;
# open FILE, "../test.$trg" or die;
#
# my $id=1;
#
# while( <FILE> )
# {
# 	chomp;
#
# 	print "<seg id=\"$id\">$_ </seg>\n";
# 	$id++;
# }
#
# print "</doc>\n</refset>\n";

# %%
# !ls
# Out:
# generate_sgms.pl  ref2sgm.pl  src2sgm.pl

# %%
# !perl ./generate_sgms.pl

# %%
# !ls
# Out:
# generate_sgms.pl  src2sgm.pl	   test.my.src.sgm  test.rk.src.sgm
# ref2sgm.pl	  test.my.ref.sgm  test.rk.ref.sgm

# %%
# !head *.sgm
# Out:
# ==> test.my.ref.sgm <==
# <refset trglang="my" setid="Rakhine-Myanmar_data" srclang="any">
# <doc sysid="ref" docid="none" genre="1811" origlang="any">
# <seg id="1">သူ အမှန်အတိုင်း မ ကျိန်ဆို ရဲ ဘူးလား </seg>
# <seg id="2">ကျွန်တော်သာဆို ပြန်ပေး လိုက်မှာ </seg>
# <seg id="3">ဆူပြီးတဲ့ ရေကို သောက် သင့်တယ် </seg>
# <seg id="4">ခင်ဗျား မေးစရာ မ လို ဘူး </seg>
# <seg id="5">သူမ ကို သူ တကယ် မ မြတ်နိုး ခဲ့ပါ </seg>
# <seg id="6">ကိုယ် မင်း ကို နားလည် ပါတယ် </seg>
# <seg id="7">ငါ အလုပ် မ ပြီး သေး ဘူး </seg>
# <seg id="8">ကျွန်တော် ဘတ်စ်ကား အတွက် အကြွေ အချို့ လို ချင်လို့ပါ </seg>
#
# ==> test.my.src.sgm <==
# <srcset setid="Rakhine-Myanmar_data" srclang="any">
# <doc docid="none" genre="1811" origlang="my">
# <seg id="1">သူ အမှန်အတိုင်း မ ကျိန်ဆို ရဲ ဘူးလား </seg>
# <seg id="2">ကျွန်တော်သာဆို ပြန်ပေး လိုက်မှာ </seg>
# <seg id="3">ဆူပြီးတဲ့ ရေကို သောက် သင့်တယ် </seg>
# <seg id="4">ခင်ဗျား မေးစရာ မ လို ဘူး </seg>
# <seg id="5">သူမ ကို သူ တကယ် မ မြတ်နိုး ခဲ့ပါ </seg>
# ...

# %% [markdown]
# ## Prepare Your Experiment Folder

# %%
# %pwd
# Out:
# '/home/ye/exp/SMT-NMT_tutorial/myrk/clean/final/test-sgm'

# %%
# %cd /home/ye/exp/SMT-NMT_tutorial/
# Out:
# /home/ye/exp/SMT-NMT_tutorial

# %%
# !mkdir aief2-pbsmt

# %%
# %cd aief2-pbsmt
# Out:
# /home/ye/exp/SMT-NMT_tutorial/aief2-pbsmt

# %% [markdown]
# ### Path Information
#
# Moses path:
# /home/ye/tool/mosesbin/ubuntu-17.04/moses/bin
#
# Data path:
# /home/ye/exp/SMT-NMT_tutorial/myrk/clean/final/
#
# Experiment path:
# /home/ye/exp/SMT-NMT_tutorial/aief2-pbsmt

# %% [markdown]
# ## Prepare SMT Configuration File

# %%
# !cp /home/ye/exp/SMT-NMT_tutorial/pbsmt-big/*.pl .

# %%
# !ls *.pl
# Out:
# generate_configs.pl  run-baseline.pl

# %% [markdown]
# After we updated paths for my-rk, rk-my SMT experiments ...

# %%
# !cat ./generate_configs.pl
# Out:
# #!/usr/bin/perl
#
# # Preparing configuration files for PBSMT experiments
# # Output: one configuration file for baseline or PBSMT
# # *** Before you run this script, you should prepare training, development and test parallel-data in advance!!!
#
# # Written by Finch-san and Ye
# # We used this script for running our NAACL paper:
# # Ye Kyaw Thu, Andrew Finch and Eiichiro Sumita,
# # "Interlocking Phrases in Phrase-based Statistical Machine Translation",
# # In Proceedings of the NAACL-HLT 2016, June 12-17, San Diego, US, pp. 1076-1081.
#
# # Last updated 9 Oct 2019, @Machine Translation Research Summer School, YTU, Myanmar
#
# use strict;
#
# my @langs;
#
# # you have to update the PBSMT experiment path!!!
# #my $smtpath = "/home/lar/experiment/kachin-myanmar/demo-mykc-smt";
# #my $smtpath = "/media/lar/Transcend/student/lecture/mtrss/pbsmt-demo/pbsmt";
# my $smtpath = "/home/ye/exp/SMT-NMT_tutorial/aief2-pbsmt";
#
# ...

# %%
# !cat ./run-baseline.pl
# Out:
# #!/usr/bin/perl
# use strict;
# use warnings;
#
# require IPC::System::Simple;
# use autodie qw(:all);
#
# # Written by Finch-san and Ye
# # We used this script for running our NAACL paper:
# # Ye Kyaw Thu, Andrew Finch and Eiichiro Sumita,
# # "Interlocking Phrases in Phrase-based Statistical Machine Translation",
# # In Proceedings of the NAACL-HLT 2016, June 12-17, San Diego, US, pp. 1076-1081.
#
# # Last updated 9 Oct 2019, @Machine Translation Research Summer School, YTU, Myanmar
#
# # You have to update following path!!!
#
# #my @configs = `find /home/ros/experiment/langacq/exp1/smt/{baseline,osm,hiero} -name "config.*" | sort`;
# #my @configs = `find /home/ros/experiment/langacq/exp2a/smt/*/ -name "config.*.*" | sort`;
# #my @configs = `find /home/ros/experiment/sl-my/smt1/*/ -name "config.baseline.*" | sort`;
# #my @configs = `find /home/ros/experiment/my-rk/smt1/*/ -name "config.baseline.*" | sort`;
# ...

# %%
# !cp /home/ye/exp/SMT-NMT_tutorial/pbsmt/*.sh .

# %%
# !cp /home/ye/exp/SMT-NMT_tutorial/pbsmt/config.baseline .

# %%
# !ls
# Out:
# config.baseline  generate_configs.pl  run-baseline.pl  run-pbsmt.sh

# %% [markdown]
# **After Updating config.baseline ...**

# %%
# !cat config.baseline
# Out:
# ### directories that contain tools and data
# #
# # moses
# #moses-src-dir = /home/ros/mosesdecoder
# #moses-src-dir = /home/lar/tool/moses/
# #moses-src-dir = /home/ye/tool/mosesbin/ubuntu-17.04/moses
# moses-src-dir = /home/ye/tool/mosesbin/ubuntu-17.04/moses
#
# # moses binaries
# moses-bin-dir = $moses-src-dir/bin
#
# # moses scripts
# moses-script-dir = $moses-src-dir/scripts
#
# # directory where GIZA++/MGIZA programs resides
# #external-bin-dir = /home/lar/tool/giza-pp-master/mkcls-v2
# #external-bin-dir = /home/lar/tool/giza-pp-master/GIZA++-v2
# #external-bin-dir = /home/lar/tool/giza-pp-master/
# #external-bin-dir = /home/ye/tool/mgiza/mgizapp/bin
# external-bin-dir = /home/ye/tool/giza-pp/GIZA++-v2
#
# # srilm
# #srilm-dir = /data/lttools/training/srilm/srilm-1.6.0/bin/i686-m64
# #I haven't installed SRILM yet on Deep Learning Box computer
# #srilm-dir = /home/ros/tool/srilm-1.7.1/bin/i686-m64
#
# # irstlm
# #irstlm-dir = $moses-src-dir/irstlm/bin
#
# # randlm
# ...

# %% [markdown]
# ## Run SMT Experiment

# %%
# !./run-pbsmt.sh
# Out:
# nohup: ignoring input and appending output to 'nohup.out'

# %%
# !head -n 100 /home/ye/exp/SMT-NMT_tutorial/aief2-pbsmt/baseline/my-rk/model/tmp/phrase-table.1
# Out:
# : ||| : ||| 0.78881 1 0.78881 1 ||| 0-0 ||| 5 5 5 ||| |||
# : ၀၀ ||| : ၀၀ ||| 0.327574 1 0.327574 1 ||| 0-0 1-1 ||| 2 2 2 ||| |||
# : ၀၀ နာရီ တိတိ ||| : ၀၀ နာရီတိတိ ||| 0.327574 0.25 0.327574 0.178715 ||| 0-0 1-1 2-2 3-2 ||| 2 2 2 ||| |||
# : ၀၀ နာရီ တိတိ မှာ ||| : ၀၀ နာရီတိတိ မာ ||| 0.327574 0.225062 0.327574 0.0728995 ||| 0-0 1-1 2-2 3-2 4-3 ||| 2 2 2 ||| |||
# : ၁၅မှ ||| : ၁၅မာ ||| 0.142559 1 0.142559 1 ||| 0-0 1-1 ||| 1 1 1 ||| |||
# : ၁၅မှ စ ||| : ၁၅မာ စ ||| 0.142559 0.854167 0.142559 0.891304 ||| 0-0 1-1 2-2 ||| 1 1 1 ||| |||
# : ၁၅မှ စ မှာ ||| : ၁၅မာ စ ဖို့ ||| 0.142559 0.194092 0.142559 0.243724 ||| 0-0 1-1 2-2 3-3 ||| 1 1 1 ||| |||
# : ၃၀မှာ ||| : ၃၀ မာ ||| 0.142559 0.126247 0.142559 0.25 ||| 0-0 1-1 1-2 ||| 1 1 1 ||| |||
# : ၃၀မှာ မန္တလေး ||| : ၃၀ မာ မန္တလေး ||| 0.142559 0.126247 0.142559 0.25 ||| 0-0 1-1 1-2 2-3 ||| 1 1 1 ||| |||
# : ၃၀မှာ မန္တလေး ထွက်မယ့် ||| : ၃၀ မာ မန္တလေး ထွက်ဖို့ ||| 0.142559 0.0194226 0.142559 0.25 ||| 0-0 1-1 1-2 2-3 3-4 ||| 1 1 1 ||| |||
# ...

# %% [markdown]
# **Language Model for target language Rakhine**

# %%
# !head -n 100 /home/ye/exp/SMT-NMT_tutorial/aief2-pbsmt/baseline/my-rk/lm/myrk.lm.1
# Out:
# \data\
# ngram 1=14632
# ngram 2=48103
# ngram 3=6867
# ngram 4=3632
# ngram 5=1881
#
# \1-grams:
# -4.7284503	<unk>	0
# 0	<s>	-0.7327764
# -1.2515326	</s>	0
# -2.2043252	မင်း	-0.17465018
# -3.0054626	ယင်းချင့်	-0.24012423
# -1.891534	ကို	-0.27694082
# -3.9416716	အခြား	-0.06648445
# -4.6226363	တစ်ခုနန့်	-0.06648445
# -1.8161794	မ	-0.42741758
# -4.6226363	ချိတ်	-0.06648445
# -2.2921176	ပါလား	-1.9336864
# -2.7113523	ထိုမချေ	-0.16528107
# -3.4390907	တစ်ယောက်လေ့	-0.20217289
# -4.6226363	မှတ်မိပါယာ	-0.06648445
# -2.2160437	ကျွန်တော်	-0.17427483
# -3.4390907	ရို့	-0.13627894
# -2.4932387	အတွက်	-0.18622202
# -4.4234405	ခက်ခ	-0.19453453
# -2.0563436	ရေ	-0.6673856
# -4.1378875	ပြောခ	-0.10511935
# -3.2929752	ရေပိုင်	-0.18871191
# -3.4149594	ယှင်းပြ	-0.15514381
# -2.473995	ခရေ	-1.0376003
# -2.922491	သူ့ကို	-0.113866426
# -4.6226363	ထိန်းဖို့	-0.06648445
# -2.9004042	ရာ	-0.2892561
# -4.4234405	တတ်နိုင်ရေ	-0.06648445
# -2.404559	ငါ	-0.20305681
# -4.4234405	တက်နင်း	-0.06648445
# ...

# %%
from IPython.display import Image

# Display a local PNG file
Image(filename='/home/ye/exp/SMT-NMT_tutorial/aief2-pbsmt/baseline/my-rk/steps/1/graph.1.300dpi.png')

# %% [markdown]
# ## Config File for my-rk Pair

# %%
# !cat /home/ye/exp/SMT-NMT_tutorial/aief2-pbsmt/baseline/my-rk/config.baseline.my-rk
# Out:
# # Config file for my-rk (baseline)
#
# [GENERAL]
# working-dir = /home/ye/exp/SMT-NMT_tutorial/aief2-pbsmt/baseline/my-rk
# input-extension = my
# output-extension = rk
# pair-extension = my-rk
#
#
# ### directories that contain tools and data
# #
# # moses
# #moses-src-dir = /home/ros/mosesdecoder
# #moses-src-dir = /home/lar/tool/moses/
# #moses-src-dir = /home/ye/tool/mosesbin/ubuntu-17.04/moses
# moses-src-dir = /home/ye/tool/mosesbin/ubuntu-17.04/moses
#
# # moses binaries
# moses-bin-dir = $moses-src-dir/bin
#
# # moses scripts
# moses-script-dir = $moses-src-dir/scripts
#
# # directory where GIZA++/MGIZA programs resides
# #external-bin-dir = /home/lar/tool/giza-pp-master/mkcls-v2
# #external-bin-dir = /home/lar/tool/giza-pp-master/GIZA++-v2
# #external-bin-dir = /home/lar/tool/giza-pp-master/
# #external-bin-dir = /home/ye/tool/mgiza/mgizapp/bin
# external-bin-dir = /home/ye/tool/giza-pp/GIZA++-v2
#
# # srilm
# ...

# %% [markdown]
# **After tuning, updated moses.ini**

# %%
# !cat /home/ye/exp/SMT-NMT_tutorial/aief2-pbsmt/baseline/my-rk/tuning/moses.tuned.ini.1
# Out:
# #########################
# ### MOSES CONFIG FILE ###
# #########################
#
# # input factors
# [input-factors]
# 0
#
# # mapping steps
# [mapping]
# 0 T 0
#
# [distortion-limit]
# 6
#
# # feature functions
# [feature]
# UnknownWordPenalty
# WordPenalty
# PhrasePenalty
# PhraseDictionaryMemory name=TranslationModel0 num-features=4 path=/home/ye/exp/SMT-NMT_tutorial/aief2-pbsmt/baseline/my-rk/model/phrase-table.1 input-factor=0 output-factor=0
# LexicalReordering name=LexicalReordering0 num-features=6 type=wbe-msd-bidirectional-fe-allff input-factor=0 output-factor=0 path=/home/ye/exp/SMT-NMT_tutorial/aief2-pbsmt/baseline/my-rk/model/reordering-table.1.wbe-msd-bidirectional-fe.gz
# Distortion
# KENLM name=LM0 factor=0 path=/home/ye/exp/SMT-NMT_tutorial/aief2-pbsmt/baseline/my-rk/lm/myrk.binlm.1 order=5
#
# # core weights
# [weight]
# LexicalReordering0= 0.0598133 0.001552 -0.0266877 0.137937 0.133709 0.0599062
# Distortion0= 0.125633
# LM0= 0.0756693
# WordPenalty0= 0.0411083
# ...

# %% [markdown]
# ## Evaluation

# %%
# !cat /home/ye/exp/SMT-NMT_tutorial/aief2-pbsmt/baseline/my-rk/evaluation/test.multi-bleu.1
# Out:
# BLEU = 58.13, 77.0/64.0/53.2/43.9 (BP=0.998, ratio=0.998, hyp_len=10641, ref_len=10657)

# %% [markdown]
# ## Check Folder Structure for my-rk

# %%
# !tree /home/ye/exp/SMT-NMT_tutorial/aief2-pbsmt/baseline/my-rk/ -L 2
# Out:
# /home/ye/exp/SMT-NMT_tutorial/aief2-pbsmt/baseline/my-rk/
# ├── config.baseline.my-rk
# ├── corpus
# │   ├── myrk.clean.1.lines-retained
# │   ├── myrk.clean.1.my
# │   └── myrk.clean.1.rk
# ├── evaluation
# │   ├── test.analysis.1
# │   ├── test.cleaned.1
# │   ├── test.detokenized.sgm.1
# │   ├── test.filtered.1
# │   ├── test.filtered.ini.1
# │   ├── test.input.txt.1
# │   ├── test.multi-bleu.1
# │   ├── test.nist-bleu.1
# │   ├── test.nist-bleu-c.1
# │   ├── test.output.1
# │   └── test.output.1.wa
# ├── lm
# │   ├── myrk.binlm.1
# │   └── myrk.lm.1
# ├── model
# │   ├── aligned.1.grow-diag-final-and
# │   ├── extract.1.inv.sorted.gz
# │   ├── extract.1.o.sorted.gz
# │   ├── extract.1.sorted.gz
# │   ├── lex.1.e2f
# │   ├── lex.1.f2e
# │   ├── moses.ini.1
# │   ├── phrase-table.1.gz
# │   ├── reordering-table.1.wbe-msd-bidirectional-fe.gz
# │   └── tmp
# ├── steps
# │   └── 1
# ├── training
# ...

# %% [markdown]
# ## Evaluation Score for rk-my

# %%
# !cat /home/ye/exp/SMT-NMT_tutorial/aief2-pbsmt/baseline/rk-my/evaluation/test.multi-bleu.1
# Out:
# BLEU = 58.01, 76.6/63.9/53.0/43.7 (BP=1.000, ratio=1.002, hyp_len=10611, ref_len=10593)

# %% [markdown]
# ## For Debugging

# %%
from IPython.display import Image

# Display a local PNG file
Image(filename='/home/ye/exp/SMT-NMT_tutorial/aief2-pbsmt/baseline/rk-my/steps/1/graph.1.rk-my.300dpi.png')

# %% [markdown]
# ## Manual Calculation of BLEU Score for my-rk
#
# Hypothesis file or translated result is as follow:

# %%
# !head /home/ye/exp/SMT-NMT_tutorial/aief2-pbsmt/baseline/my-rk/evaluation/test.cleaned.1
# Out:
# သူ အမှန်အတိုင်း မ ကျိန်ဆို ရဲ ပါလား
# ကျွန်တော်သာဆို ပြန်ပီး လိုက်ဖို့
# ဆူပြီးတဲ့ ရီကို သောက် သင့်ရေ
# မင်း မိန်းစရာ မ လို ပါ
# ထိုမချေ ကို သူ အဂယောင့် မ မြတ်နိုး ခပါ
# ကိုယ် မင်း ကို နားလည် ပါရေ
# ငါ အလုပ် မ ပြီး သိ ပါ
# ကျွန်တော် ဘတ်စ်ကား အတွက် အကြွီ အချို့ လို ချင်လို့ပါ
# မိုး ချက်ချင်း ရွာတဲ့အခါ သူရို့ဘာတွေ လုပ် နီစွာလေး
# မင်း တောင်တွေကို တက်နီ ကျလား

# %%
# !wc /home/ye/exp/SMT-NMT_tutorial/aief2-pbsmt/baseline/my-rk/evaluation/test.cleaned.1
# Out:
#   1811  10641 200114 /home/ye/exp/SMT-NMT_tutorial/aief2-pbsmt/baseline/my-rk/evaluation/test.cleaned.1

# %% [markdown]
# Here is our reference file for Rakhine:

# %%
# !head /home/ye/exp/SMT-NMT_tutorial/myrk/clean/final/test.rk
# Out:
# သူ အမှန်အတိုင်း မ ကျိန်ဆို ရဲ ပါလား
# ကျွန်တော်ဆိုကေ ပြန်ပီး လိုက်ဖို့
# ဆူပြီး ရီကို သောက် သင့်ရေ
# မင်း မိန်းစရာ မ လို ပါ
# ထိုမချေ ကို သူ အမှန် မ မြတ်နိုး ခပါ
# ကိုယ် မင်း ကို နားလည် ပါရေ
# ငါ အလုပ် မ ပြီး သိ ပါ
# ငါ ဘတ်စ်ကား စီးဖို့ အတွက် အကြွီ လို ချင်ရေ
# မိုး ချက်ချင်း ရွာရေအခါ သူရို့ ဇာတိ လုပ် နီစွာ
# မင်း တောင်တိကို တက်နီ ကျလား

# %%
# !perl /home/ye/tool/mosesbin/ubuntu-17.04/moses/scripts/generic/multi-bleu.perl
# Out:
# Use of uninitialized value $ARGV[0] in string eq at /home/ye/tool/mosesbin/ubuntu-17.04/moses/scripts/generic/multi-bleu.perl line 11.
# usage: multi-bleu.pl [-lc] reference < hypothesis
# Reads the references from reference or reference0, reference1, ...

# %%
# !perl /home/ye/tool/mosesbin/ubuntu-17.04/moses/scripts/generic/multi-bleu.perl /home/ye/exp/SMT-NMT_tutorial/myrk/clean/final/test.rk < /home/ye/exp/SMT-NMT_tutorial/aief2-pbsmt/baseline/my-rk/evaluation/test.cleaned.1
# Out:
# BLEU = 58.13, 77.0/64.0/53.2/43.9 (BP=0.998, ratio=0.998, hyp_len=10641, ref_len=10657)

# %% [markdown]
# ## Evaluation with chrF++ for my-rk

# %%
# !python /home/ye/tool/chrF/chrF++.py --help
# Out:
# start_time:	1789813878
# usage: chrF++.py [-h] -R REFERENCE -H HYPOTHESIS [-nc NCORDER] [-nw NWORDER]
#                  [-b BETA] [-s]
#
# options:
#   -h, --help            show this help message and exit
#   -R REFERENCE, --reference REFERENCE
#                         reference translation
#   -H HYPOTHESIS, --hypothesis HYPOTHESIS
#                         hypothesis translation
#   -nc NCORDER, --ncorder NCORDER
#                         character n-gram order (default=6)
#   -nw NWORDER, --nworder NWORDER
#                         word n-gram order (default=2)
#   -b BETA, --beta BETA  beta parameter (default=2)
#   -s, --sent            show sentence level scores

# %%
# !python /home/ye/tool/chrF/chrF++.py -R /home/ye/exp/SMT-NMT_tutorial/myrk/clean/final/test.rk -H /home/ye/exp/SMT-NMT_tutorial/aief2-pbsmt/baseline/my-rk/evaluation/test.cleaned.1
# Out:
# start_time:	1789813944
# c6+w2-F2	82.0450
# c6+w2-avgF2	82.6479
# end_time:	1789813944

# %% [markdown]
# ## Evaluation with chrF++ for rk-my

# %%
# !python /home/ye/tool/chrF/chrF++.py -R /home/ye/exp/SMT-NMT_tutorial/myrk/clean/final/test.my -H /home/ye/exp/SMT-NMT_tutorial/aief2-pbsmt/baseline/rk-my/evaluation/test.cleaned.1
# Out:
# start_time:	1789814062
# c6+w2-F2	80.1462
# c6+w2-avgF2	80.7639
# end_time:	1789814062
